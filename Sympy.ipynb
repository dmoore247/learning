# %% [markdown]
# # Introduction
# Play with sympy (Symbolic math)

# %%
# %%sh
# conda install --yes sympy pandas matplotlib
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /anaconda3/envs/jupyterlab
#
#   added / updated specs:
#     - matplotlib
#     - pandas
#     - sympy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     matplotlib-3.0.2           |   py37h54f8f79_0         6.5 MB
#     numpy-base-1.15.4          |   py37h6575580_0         4.1 MB
#     libgfortran-3.0.1          |       h93005f0_2         495 KB
#     mkl_random-1.0.2           |   py37h27c97d8_0         358 KB
#     numpy-1.15.4               |   py37hacdab7b_0          47 KB
#     sympy-1.3                  |           py37_0         9.5 MB
#     mkl-2019.1                 |              144       154.4 MB
#     intel-openmp-2019.1        |              144         1.1 MB
#     blas-1.0                   |              mkl           5 KB
# ...

# %%
from sympy import *
from sympy.plotting import plot, plot_parametric
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
c, w, x, y, z = symbols('c w x y z')

# %%
init_printing()

# %%
eq1 = x*x + y*y*y
eq2 = w*w + z*z*z
eq = eq1 - eq2

# %%
solve(eq)
# Out:
# ⎡⎧       ______________⎫  ⎧      ______________⎫⎤
# ⎢⎨      ╱  2    3    3 ⎬  ⎨     ╱  2    3    3 ⎬⎥
# ⎣⎩w: -╲╱  x  + y  - z  ⎭, ⎩w: ╲╱  x  + y  - z  ⎭⎦

# %%
for c in range(1,20000):
    for w in range(1, c):
        for x in range (1, c):
            if c == w*w*w + x*x and w < x:
                for y in range (1, c):
                    for z in range (1, c):
                        if (c == y*y*y + z*z) and c == w*w*w + x*x and w < y and x != y and w != z and y != z and x != w and x != z:
                            print (c,w,x,y,z)
# Out:
# (17, 1, 4, 2, 3)
# (89, 2, 9, 4, 5)
# (108, 2, 10, 3, 9)
# (145, 1, 12, 4, 9)
# (225, 5, 10, 6, 3)
# (233, 2, 15, 4, 13)
# (297, 2, 17, 6, 9)
# (316, 3, 17, 6, 10)
# (388, 3, 19, 4, 18)
# (449, 2, 21, 5, 18)
# (464, 4, 20, 7, 11)
# (505, 4, 21, 6, 17)
# (537, 2, 23, 8, 5)
# (548, 4, 22, 8, 6)
# (577, 1, 24, 6, 19)
# (593, 4, 23, 8, 9)
# (633, 2, 25, 8, 11)
# (737, 2, 27, 8, 15)
# (745, 6, 23, 9, 4)
# (792, 2, 28, 6, 24)
# (793, 4, 27, 9, 8)
# (801, 5, 26, 8, 17)
# (873, 8, 19, 9, 12)
# (1025, 1, 32, 4, 31)
# (1025, 1, 32, 5, 30)
# (1025, 1, 32, 10, 5)
# (1025, 4, 31, 5, 30)
# (1025, 4, 31, 10, 5)
# (1088, 4, 32, 8, 24)
# (1090, 1, 33, 9, 19)
# (1116, 3, 33, 6, 30)
# (1289, 4, 35, 10, 17)
# (1304, 2, 36, 7, 31)
# (1305, 6, 33, 9, 24)
# (1367, 7, 32, 11, 6)
# (1412, 8, 30, 11, 9)
# (1441, 6, 35, 10, 21)
# (1529, 2, 39, 10, 23)
# (1585, 4, 39, 6, 37)
# (1601, 1, 40, 8, 33)
# (1729, 10, 27, 12, 1)
# (1737, 6, 39, 8, 35)
# (1737, 6, 39, 12, 3)
# (1737, 8, 35, 12, 3)

# %%
eq = x ** 3 - 2 * x - 1
solve(eq)
# Out:
# ⎡    1   √5    √5   1⎤
# ⎢-1, ─ + ──, - ── + ─⎥
# ⎣    2   2     2    2⎦

# %%
plot(eq)

# %%
range = 50
plot(cos(2*x) + sin(x/2), (x, -range, range))

# %%
from sympy.plotting import plot3d
plot3d(x*y, -x*y, (x, -5, 5), (y, -5, 5))

# %%
plot3d(1+x*x+y*y,(x, -5, 5), (y, -5, 5))

# %%
from sympy import symbols, cos, sin
from sympy.plotting import plot3d_parametric_line
u = symbols('u')
r = 5*pi
plot3d_parametric_line(cos(u), sin(u), u, (u, -r, r))

# %%
u,v = symbols('u v')
from sympy.plotting import plot3d_parametric_surface
plot3d_parametric_surface(cos(u + v), sin(u - v), u - v, (u, -5, 5), (v, -5, 5))

# %%
from sympy import plot_implicit, symbols, Eq, And
plot_implicit(Eq(x**2 + y**2, 5))

# %%
plot_implicit(And(y > x, y > -x))

# %%
# %%sh
# pip install pyglet

# %%
import pyglet
#from sympy import var, Plot

# %%
from sympy import log, E
n = Symbol('n')

# %%
plot(log(E**sin(x)))

# %%
factorial(10)
# Out:
# 3628800

# %%
(pi, 2*pi) * 10
# Out:
# (π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅π, π, 2⋅
# π)

# %%
Float(22./7.)
# Out:
# 3.14285714285714

# %%
pi.evalf(100)-66./21.
# Out:
# -0.001264489267349555238898066711551948738163852578019179025055407692183593713
# 791001371965174657882932021

# %%
E.evalf(10000)
# Out:
# 2.7182818284590452353602874713526624977572470936999595749669676277240766303535
# 475945713821785251664274274663919320030599218174135966290435729003342952605956
# 307381323286279434907632338298807531952510190115738341879307021540891499348841
# 675092447614606680822648001684774118537423454424371075390777449920695517027618
# 386062613313845830007520449338265602976067371132007093287091274437470472306969
# 772093101416928368190255151086574637721112523897844250569536967707854499699679
# 468644549059879316368892300987931277361782154249992295763514822082698951936680
# 331825288693984964651058209392398294887933203625094431173012381970684161403970
# 198376793206832823764648042953118023287825098194558153017567173613320698112509
# 961818815930416903515988885193458072738667385894228792284998920868058257492796
# 104841984443634632449684875602336248270419786232090021609902353043699418491463
# 140934317381436405462531520961836908887070167683964243781405927145635490613031
# ...

# %%
(pi+E).evalf(100)
# Out:
# 5.8598744820488384738229308546321653819544164930750653959419122200318930366397
# 56593199417003867283495

# %%
sin(pi)
# Out:
# 0

# %%
y = x**3
(y, Integral(y,x), integrate(y, x), diff(y))
# Out:
# ⎛    ⌠         4      ⎞
# ⎜ 3  ⎮  3     x      2⎟
# ⎜x , ⎮ x  dx, ──, 3⋅x ⎟
# ⎝    ⌡        4       ⎠

# %%
plot(erf( x ))

# %%
y=(2-3*x)/(x-4)
plot(y)
